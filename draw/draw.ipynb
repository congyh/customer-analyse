# %%
import numpy as np
# 导入3D绘图模块, 传统的Matplotlib并不支持3d绘图
from mpl_toolkits.mplot3d import Axes3D

# %%
customerId, r, f, m = np.loadtxt('/home/congyihao/PythonProjects/chen20170509/data/rfm_normalize30.csv',
                                 delimiter=',',
                                 unpack=True, skiprows=1)
# 验证了数据读取格式
print('=========== 验证数据读取格式 ===============')
print('r:', r[0], 'f:', f[0], 'm:', m[0], sep=' ')

fig = figure()
# 设置投影方式为3d图
ax = fig.add_subplot(111, projection='3d')

# 绘制散点图
ax.scatter(r, f, m, alpha=.5, s=10)
# TODO 添加坐标轴
show()
# Out:
# =========== 验证数据读取格式 ===============
# r: 0.489173237944 f: 0.440417758066 m: 0.0704090039904
